# %% [markdown]
# # Installing Anaconda on Windows

# %% [markdown]
# ## Download and Install Anaconda

# %% [markdown]
# Go to the Anaconda Website and choose a Python 3.x graphical installer (A) or a Python 2.x graphical installer (B). If you aren't sure which Python version you want to install, choose Python 3. Do not choose both.

# %% [markdown]
# ![image.png](attachment:0c903df2-48e3-47a2-955c-519363db8ad5.png)

# %% [markdown]
# Locate your download and double click it.

# %% [markdown]
# ![image.png](attachment:5e049c4e-85e4-4ff2-bcdc-0346357b0cee.png)

# %% [markdown]
# When the screen below appears, click on Next.

# %% [markdown]
# ![image.png](attachment:2f84f00f-0f7a-44a5-92aa-b652a9c7e7ae.png)

# %% [markdown]
# Read the license agreement and click on I Agree.

# %% [markdown]
# ![image.png](attachment:87a2c7f9-ac02-4828-b018-0248ef4c35ff.png)

# %% [markdown]
#  Click on Next.

# %% [markdown]
# ![image.png](attachment:2adab890-c303-40f5-b19a-421719f57316.png)

# %% [markdown]
# Note your installation location and then click Next.

# %% [markdown]
# ![image.png](attachment:79c7f90e-c611-45a1-9180-faaa6e29e4e0.png)

# %% [markdown]
# This is an important part of the installation process. The recommended approach is to not check the box to add Anaconda to your path. This means you will have to use Anaconda Navigator or the Anaconda Command Prompt (located in the Start Menu under "Anaconda") when you wish to use Anaconda (you can always add Anaconda to your PATH later if you don't check the box). If you want to be able to use Anaconda in your command prompt (or git bash, cmder, powershell etc), please use the alternative approach and check the box.

# %% [markdown]
# ![image.png](attachment:07cf12c9-6b31-4504-9a1d-ce231164a51a.png)

# %% [markdown]
# Click on Finish.

# %% [markdown]
# ![image.png](attachment:7e04c5f2-a7e8-4b85-a66b-b77c97a5e765.png)

# %% [markdown]
# # Installing Jupyter Notebook on Windows.

# %% [markdown]
# ## Installing Jupyter Notebook using Anaconda:

# %% [markdown]
# Install Python and Jupyter using the Anaconda Distribution, which includes Python, the Jupyter Notebook, and other commonly used packages for scientific computing and data science

# %% [markdown]
# * Launch Anaconda Navigator.
# * Click on the Install Jupyter Notebook Button.
# * Beginning the Installation.
# * Loading Packages.
# * Finish Installation.

# %% [markdown]
# ## Installing Jupyter Notebook using pip :

# %% [markdown]
# PIP is a package management system used to install and manage software packages/libraries written in Python. These files are stored in a large “on-line repository” termed as Python Package Index (PyPI).
# pip uses PyPI as the default source for packages and their dependencies.
#
# To install Jupyter using pip, we need to first check if pip is updated in our system. Use the following command to update pip

# %% [markdown]
# python -m pip install --upgrade pip

# %% [markdown]
# **Command to install Jupyter:**

# %% [markdown]
# python -m pip install jupyter

# %% [markdown]
# **Once installation is done you can use the following command to launch Jupyter using command-line**

# %% [markdown]
# jupyter notebook

# %% [markdown]
# Some of the other packages that you can install using pip that will be needed from the command line/terminal are NumPy, Pandas, Keras, PyTorch, Tensorflow, Matplotlib. A simple google search along the lines of **pip install 'packageName'** should give you the right command.
